# %%
import pandas as pd
import numpy as np
import itertools

# %%
from tqdm import tqdm

# %%
def findsubsets(sett, n):
    return list(itertools.combinations(sett, n))

# %%
def support_calc(itemset):
    support=0
    for i in range(basket_numbers):
        if set(itemset).issubset(set(baskets[i])):
            support=support+1
            
    return support

# %%
file = open('records .txt',"r")

# %%
baskets = []
basket_numbers=31101
for i in range(31101):
    line = file.readline()
    baskets.append(list(set(line.split())))

# %%
! pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 281.4 MB 43 kB/s
# ...
#      |████████████████████████████████| 199 kB 45.5 MB/s
# ...
#   Created wheel for pyspark: filename=pyspark-3.3.1-py2.py3-none-any.whl size=281845512 sha256=18fc5cc6354551c132af9eea00a9c3c27ea98d5e472a52ce6728420ca3929310
#   Stored in directory: /root/.cache/pip/wheels/43/dc/11/ec201cd671da62fa9c5cc77078235e40722170ceba231d7598
# Successfully built pyspark
# ...

# %%
from pyspark.sql import SparkSession
spark = SparkSession \
    .builder \
    .appName("MDA_2021") \
    .master("local[*]") \
    .getOrCreate()

sc=spark.sparkContext

# %%
baskets_rdd = sc.parallelize(baskets)

# %%
items_rdd = baskets_rdd.flatMap(lambda x: x)

# %%
items_KV_rdd= items_rdd.map(lambda x: (x, 1)) # (key = item, value = 1)

items_count_rdd= items_KV_rdd.reduceByKey(lambda x, y: x + y) # (key = item, value = num)

# %%
s = 100
frequent_single_rdd=items_count_rdd.filter(lambda x :x[1]>=s)

# %%
frequent_single_rdd.count()
# Out:
# 647

# %%
freq_single_KV=frequent_single_rdd.collect()

# %%
freq_single=[]
for i in range(len(freq_single_KV)):
    freq_single.append(freq_single_KV[i][0])

# %%
candidate_pairs = findsubsets(freq_single,2)
len(candidate_pairs)
# Out:
# 208981

# %%
candidate_pairs[:10]
# Out:
# [('FRO11987', 'SNA90258'),
#  ('FRO11987', 'SNA80192'),
#  ('FRO11987', 'ELE52966'),
#  ('FRO11987', 'GRO73461'),
#  ('FRO11987', 'FRO86643'),
#  ('FRO11987', 'DAI22896'),
#  ('FRO11987', 'GRO39357'),
#  ('FRO11987', 'SNA69641'),
#  ('FRO11987', 'ELE11375'),
#  ('FRO11987', 'DAI50921')]

# %%
# freq_pair_KV=[]
# for i in range(len(candidate_pairs)):
#     supp=support_calc(candidate_pairs[i])
#     if supp>=100:
#       freq_pair_KV.append((candidate_pairs[i],supp))

# %%
# f = open("freq_pairs", "w")
# f.write(str(freq_pair_KV))
# f.close()

# %%
# f=open('freq_pairs.txt','r')
# freq_pair_KV= f.readline()

# %%
freq_pair_KV=[(('SNA90258', 'ELE17451'), 113), (('SNA90258', 'GRO99222'), 156), (('SNA90258', 'DAI62779'), 114), (('DAI22896', 'GRO73461'), 304), (('DAI22896', 'SNA72163'), 227), (('DAI22896', 'FRO31317'), 167), (('DAI22896', 'ELE32164'), 107), (('DAI22896', 'SNA80324'), 195), (('DAI22896', 'DAI75645'), 215), (('DAI22896', 'ELE74009'), 165), (('DAI22896', 'ELE17451'), 193), (('DAI22896', 'GRO30386'), 102), (('DAI22896', 'DAI62779'), 297), (('DAI22896', 'FRO40251'), 154), (('DAI22896', 'GRO61133'), 110), (('DAI22896', 'GRO
), (('DAI88807', 'GRO59710'), 139), (('DAI88807', 'DAI62779'), 261), (('DAI88807', 'FRO40251'), 146), (('DAI88807', 'GRO69543'), 109), (('DAI88807', 'GRO61133'), 111), (('DAI88807', 'GRO21487'), 140), (('DAI88807', 'GRO38814'), 102), (('DAI88807', 'FRO53271'), 139), (('DAI88807', 'DAI31081'), 134), (('DAI88807', 'FRO80039'), 129), (('DAI88807', 'DAI42493'), 118), (('ELE85027', 'DAI62779'), 119), (('FRO66272', 'DAI85309'), 138), (('FRO66272', 'ELE17451'), 117), (('FRO66272', 'DAI62779'), 276), (('FRO66272', 'FRO43226'), 114), (('DAI88079', 'SNA80324'), 142), (('DAI88079', 'DAI75645'), 149), (('DAI88079', 'ELE17451'), 124), (('DAI88079', 'DAI62779'), 117), (('DAI88079', 'FRO40251'), 446), (('SNA80324', 'DAI75645'), 1130), (('SNA80324', 'SNA96271'), 219), (('SNA80324', 'GRO50832'), 108), (('SNA80324', 'SNA38068'), 123), (('SNA80324', 'ELE74009'), 224), (('SNA80324', 'GRO56726'), 169), (('SNA80324', 'FRO75586'), 133), (('SNA80324', 'ELE56788'), 148), (('SNA80324', 'GRO88324'), 106), (('SNA80324', 'ELE74482'), 114), (('SNA80324', 'FRO61354'), 176), (('SNA80324', 'SNA44190'), 112), (('SNA80324', 'GRO64900'), 119), (('SNA80324', 'GRO71621'), 254), (('SNA80324', 'ELE20847'), 410), (('SNA80324', 'DAI55148'), 339), (('SNA80324', 'DAI85309'), 187), (('SNA80324', 'ELE17451'), 597), (('SNA80324', 'GRO99222'), 101), (('SNA80324', 'ELE26917'), 267), (('SNA80324', 'SNA99873'), 163), (('SNA80324', 'FRO78087'), 170), (('SNA80324', 'GRO94758'), 218), (('SNA80324', 'FRO32293'), 156), (('SNA80324', 'GRO30386'), 238), (('SNA80324', 'SNA93860'), 150), (('SNA80324', 'GRO15017'), 198), (('SNA80324', 'ELE66600'), 129), (('SNA80324', 'ELE14480'), 100), (('SNA80324', 'DAI62779'), 923), (('SNA80324', 'SNA55762'), 201), (('SNA80324', 'SNA45677'), 256), (('SNA80324', 'FRO40251'), 1412), (('SNA80324', 'GRO69543'), 102), (('SNA80324', 'GRO44993'), 111), (('SNA80324', 'GRO61133'), 171), (('SNA80324', 'GRO81087'), 185), (('SNA80324', 'GRO35122'), 155), (('SNA80324', 'ELE53126'), 101), (('SNA80324', 'ELE37048'), 106), (('SNA80324', 'GRO21487'), 225), (('SNA80324', 'FRO92469'), 352), (('SNA80324', 'GRO38814'), 214), (('SNA80324', 'ELE99737'), 104), (('SNA80324', 'DAI83948'), 139), (('SNA80324', 'FRO35904'), 135), (('SNA80324', 'FRO53271'), 196), (('SNA80324', 'SNA90094'), 154), (('SNA80324', 'DAI31081'), 189), (('SNA80324', 'DAI83733'), 196), (('SNA80324', 'FRO80039'), 205), (('SNA80324', 'DAI42493'), 125), (('SNA80324', 'GRO46854'), 178), (('SNA80324', 'ELE92920'), 118), (('SNA
('GRO21487', 'FRO80039'), 136), (('GRO21487', 'DAI42493'), 108), (('GRO21487', 'GRO46854'), 209), (('GRO38814', 'FRO53271'), 121), (('GRO38814', 'DAI83733'), 130), (('GRO38814', 'FRO80039'), 115), (('GRO38814', 'GRO46854'), 103), (('ELE99737', 'SNA90094'), 102), (('ELE99737', 'ELE34057'), 106), (('ELE99737', 'FRO80039'), 146), (('FRO35904', 'ELE12845'), 174), (('FRO35904', 'DAI83733'), 107), (('FRO35904', 'GRO46854'), 128), (('FRO35904', 'FRO99783'), 122), (('FRO53271', 'DAI31081'), 161), (('FRO53271', 'FRO80039'), 112), (('FRO53271', 'DAI42493'), 103), (('SNA90094', 'GRO46854'), 166), (('ELE34057', 'FRO80039'), 124), (('ELE34057', 'GRO46854'), 113), (('SNA30859', 'GRO24246'), 119), (('DAI83733', 'FRO80039'), 156), (('DAI83733', 'GRO46854'), 189), (('DAI83733', 'ELE92920'), 111), (('DAI83733', 'FRO79022'), 113), (('FRO80039', 'GRO46854'), 122), (('FRO80039', 'SNA96466'), 102), (('GRO30912', 'ELE88583'), 105), (('DAI42493', 'ELE92920'), 142), (('GRO46854', 'SNA66583'), 100), (('GRO46854', 'ELE92920'), 101), (('GRO46854', 'FRO79022'), 222), (('GRO46854', 'FRO99783'), 128), (('GRO46854', 'GRO81045'), 143), (('ELE92920', 'DAI23334'), 143), (('FRO79022', 'FRO99783'), 172), (('DAI94679', 'DAI83031'), 141)]

# %%
len(freq_pair_KV)
# Out:
# 1334

# %%
freq_pair_splited=[]
for  i  in range(len(freq_pair_KV)):
      freq_pair_splited.append(freq_pair_KV[i][0][0])
      freq_pair_splited.append(freq_pair_KV[i][0][1])

# %%
freq_pair_splited= list(set(freq_pair_splited))

# %%
len(freq_pair_splited)
# Out:
# 222

# %%
candidate_triples = findsubsets(freq_pair_splited,3)
len(candidate_triples)
# Out:
# 1798940

# %%
freq_pair=[]
for  i  in range(len(freq_pair_KV)):
      freq_pair.append(freq_pair_KV[i][0])

# %%
final_candidate_triples=[]
for i in tqdm(range(len(candidate_triples))):
    subs_of_candidate=findsubsets(candidate_triples[i],2)
    flag=0
    for j in range(len(freq_pair)):
        if subs_of_candidate[0]==freq_pair[j]:
            flag=flag+1
        if subs_of_candidate[1]==freq_pair[j]:
            flag=flag+1
        if subs_of_candidate[2]==freq_pair[j]:
            flag=flag+1
    if flag==3:
        final_candidate_triples.append(candidate_triples[i])
# Out:
# 100%|██████████| 1798940/1798940 [16:11<00:00, 1851.72it/s]

# %%
len(final_candidate_triples)
# Out:
# 1900

# %%
basket_numbers=31101

# %%
freq_triples_KV=[]
for i in tqdm(range(len(final_candidate_triples))):
    supp=support_calc(final_candidate_triples[i])
    if supp>=100:
        freq_triples_KV.append((final_candidate_triples[i],supp))
# Out:
# 100%|██████████| 1900/1900 [01:09<00:00, 27.25it/s]

# %%
len(freq_triples_KV)
# Out:
# 79

# %%
print(freq_triples_KV)
# Out:
# [(('ELE78169', 'GRO94758', 'SNA45677'), 115), (('DAI55148', 'ELE17451', 'DAI62779'), 150), (('FRO31317', 'ELE17451', 'DAI62779'), 106), (('GRO59710', 'DAI62779', 'DAI43223'), 205), (('GRO59710', 'DAI62779', 'ELE92920'), 116), (('SNA80324', 'DAI75645', 'FRO92469'), 119), (('SNA80324', 'DAI75645', 'ELE26917'), 130), (('SNA80324', 'DAI75645', 'FRO40251'), 550), (('SNA80324', 'DAI75645', 'ELE20847'), 164), (('SNA80324', 'DAI75645', 'ELE17451'), 300), (('SNA80324', 'DAI75645', 'GRO38814'), 102), (('SNA80324', 'DAI75645', 'DAI62779'), 421), (('SNA80324', 'DAI75645', 'GRO30386'), 131), (('SNA80324', 'DAI75645', 'GRO94758'), 120), (('SNA80324', 'DAI75645', 'GRO81087'), 108), (('SNA80324', 'DAI75645', 'SNA45677'), 111), (('SNA80324', 'DAI75645', 'ELE74009'), 106), (('SNA80324', 'SNA96271', 'FRO40251'), 112), (('SNA80324', 'ELE26917', 'FRO40251'), 133), (('SNA80324', 'FRO40251', 'GRO38814'), 106), (('SNA80324', 'FRO40251', 'GRO21487'), 118), (('SNA80324', 'FRO40251', 'GRO81087'), 109), (('SNA8
# ...

# %% [markdown]
# Confidence score

# %%
#one to one rules from freq pairs

# %%
one_to_one_confidence=[]
for i in tqdm(range(len(freq_pair_KV))):
  flag=0
  for j in range(len(freq_single_KV)):
    if freq_single_KV[j][0]==freq_pair_KV[i][0][0]:
      one_to_one_confidence.append(((freq_pair_KV[i][0][0]+'--->',freq_pair_KV[i][0][1]),round(freq_pair_KV[i][1]/freq_single_KV[j][1],4)))
      flag=flag+1

    if freq_single_KV[j][0]==freq_pair_KV[i][0][1]:
      one_to_one_confidence.append(((freq_pair_KV[i][0][1]+'--->',freq_pair_KV[i][0][0]),round(freq_pair_KV[i][1]/freq_single_KV[j][1],4)))
      flag=flag+1
    if flag==2:
      break
# Out:
# 100%|██████████| 1334/1334 [00:00<00:00, 6021.23it/s]

# %%
sorted(one_to_one_confidence,key=lambda x: x[1],reverse=True)
# Out:
# [(('DAI93865--->', 'FRO40251'), 1.0),
#  (('GRO85051--->', 'FRO40251'), 0.9992),
#  (('GRO38636--->', 'FRO40251'), 0.9907),
#  (('ELE12951--->', 'FRO40251'), 0.9906),
#  (('DAI88079--->', 'FRO40251'), 0.9867),
#  (('FRO92469--->', 'FRO40251'), 0.9835),
#  (('DAI43868--->', 'SNA82528'), 0.973),
#  (('DAI23334--->', 'DAI62779'), 0.9545),
#  (('ELE92920--->', 'DAI62779'), 0.7327),
#  (('DAI53152--->', 'FRO40251'), 0.7179),
#  (('SNA18336--->', 'DAI62779'), 0.7137),
#  (('ELE55848--->', 'GRO32086'), 0.7095),
#  (('GRO89004--->', 'ELE25077'), 0.6981),
#  (('GRO81647--->', 'GRO73461'), 0.6776),
#  (('DAI37288--->', 'ELE32164'), 0.6464),
#  (('SNA18336--->', 'ELE92920'), 0.6417),
#  (('ELE32244--->', 'ELE66600'), 0.6404),
#  (('FRO47962--->', 'DAI75645'), 0.6176),
#  (('FRO73056--->', 'GRO44993'), 0.6016),
#  (('FRO19221--->', 'DAI62779'), 0.5977),
#  (('SNA44451--->', 'DAI18527'), 0.5829),
#  (('FRO17734--->', 'ELE28189'), 0.5816),
#  (('DAI46755--->', 'FRO81176'), 0.5804),
# ...

# %%
#two to one rules from freq triples

# %%
two_to_one_confidence=[]
for i in tqdm(range(len(freq_triples_KV))):
  flag=0
  for j in range(len(freq_pair_KV)):
    if freq_pair_KV[j][0]==(freq_triples_KV[i][0][0],freq_triples_KV[i][0][1]):
      two_to_one_confidence.append(((freq_triples_KV[i][0][0],freq_triples_KV[i][0][1]+'--->',freq_pair_KV[i][0][1]),round(freq_triples_KV[i][1]/freq_pair_KV[j][1],4)))
      flag=flag+1

    if freq_pair_KV[j][0]==(freq_triples_KV[i][0][0],freq_triples_KV[i][0][2]):
      two_to_one_confidence.append(((freq_triples_KV[i][0][0],freq_triples_KV[i][0][2]+'--->',freq_pair_KV[i][0][0]),round(freq_triples_KV[i][1]/freq_pair_KV[j][1],4)))
      flag=flag+1

    if freq_pair_KV[j][0]==(freq_triples_KV[i][0][1],freq_triples_KV[i][0][2]):
      two_to_one_confidence.append(((freq_triples_KV[i][0][1],freq_triples_KV[i][0][2]+'--->',freq_pair_KV[i][0][0]),round(freq_triples_KV[i][1]/freq_pair_KV[j][1],4)))
      flag=flag+1
      
    if flag==3:
      break
# Out:
# 100%|██████████| 79/79 [00:00<00:00, 1159.10it/s]

# %%
len(two_to_one_confidence)
# Out:
# 237

# %%
sorted(two_to_one_confidence,key=lambda x: x[1],reverse=True)
# Out:
# [(('GRO81087', 'ELE92920--->', 'GRO73461'), 0.9571),
#  (('SNA18336', 'ELE92920--->', 'GRO73461'), 0.9495),
#  (('SNA18336', 'GRO15017--->', 'GRO88511'), 0.9292),
#  (('DAI83733', 'ELE92920--->', 'GRO73461'), 0.9279),
#  (('SNA18336', 'ELE17451--->', 'GRO71621'), 0.9139),
#  (('ELE17451', 'ELE92920--->', 'GRO73461'), 0.8984),
#  (('GRO15017', 'ELE92920--->', 'GRO73461'), 0.8882),
#  (('SNA18336', 'ELE17451--->', 'FRO47962'), 0.8539),
#  (('SNA18336', 'DAI62779--->', 'GRO32086'), 0.8538),
#  (('SNA53220', 'FRO19221--->', 'SNA99873'), 0.8452),
#  (('GRO59710', 'ELE92920--->', 'DAI22896'), 0.8227),
#  (('GRO73461', 'FRO47962--->', 'GRO73461'), 0.8102),
#  (('SNA18336', 'DAI85309--->', 'ELE20847'), 0.8035),
#  (('DAI75645', 'ELE92920--->', 'GRO73461'), 0.7927),
#  (('ELE32164', 'ELE92920--->', 'GRO73461'), 0.7366),
#  (('GRO73461', 'FRO19221--->', 'DAI88079'), 0.703),
#  (('SNA80324', 'ELE17451--->', 'SNA55952'), 0.6985),
#  (('ELE17451', 'DAI43223--->', 'GRO73461'), 0.6963),
# ...
